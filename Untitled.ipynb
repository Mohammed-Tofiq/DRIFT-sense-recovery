# %%
# !python generate_dataset.py
# Out:
# generating train: 100%|████████████████████| 5000/5000 [02:45<00:00, 30.24it/s]
# [train] wrote 5000 pairs -> dataset/train/labels.csv  (165.5s, 10 workers, chunksize=125)
# generating val: 100%|████████████████████████| 200/200 [00:10<00:00, 18.74it/s]
# [val] wrote 200 pairs -> dataset/val/labels.csv  (10.7s, 10 workers, chunksize=5)
# wrote dataset/meta.json

# %%
# !python src/dl_training.py
# Out:
# Selected Acceleration Device: mps
# TrainConfig(dataset_root='dataset', embed_dim=16, batch_size=32, epochs=45, lr=0.002, weight_decay=0.0001, pos_radius=1.0, exclusion_radius=6.0, margin=0.3, lambda_margin=1.0, init_logit_scale=10.0, num_workers=0, seed=42, checkpoint_path='drift_sense_model.pth', augment=True)
# Dataset Loaded. Scale ratio: 10.0
# [01/45] Train Loss 0.6822 (BCE 0.4971) | Val Err Mean  6.61px | Acc@5px 99.5% | Epoch Time: 152.8s
# [02/45] Train Loss 0.2738 (BCE 0.2714) | Val Err Mean  6.52px | Acc@5px 99.5% | Epoch Time: 200.2s
# [03/45] Train Loss 0.2660 (BCE 0.2648) | Val Err Mean 14.87px | Acc@5px 98.5% | Epoch Time: 211.7s
# [04/45] Train Loss 0.2634 (BCE 0.2625) | Val Err Mean  6.42px | Acc@5px 99.5% | Epoch Time: 230.5s
# [05/45] Train Loss 0.2605 (BCE 0.2599) | Val Err Mean 12.27px | Acc@5px 98.5% | Epoch Time: 218.2s
# [06/45] Train Loss 0.2588 (BCE 0.2586) | Val Err Mean  6.42px | Acc@5px 99.5% | Epoch Time: 214.8s
# ...

# %%
# !python localize.py
# Out:
# ═══════════════════════════════════════════════════════
#  🚀 DRIFT-SENSE EVALUATION REPORT
# ═══════════════════════════════════════════════════════
#  💻 SYSTEM CONFIGURATION
#     Hardware         : MPS Acceleration
#     Timing Method    : Python time.perf_counter()
#     Total Pairs      : 200
# -------------------------------------------------------
#  🎯 ERROR STATISTICS (Pixels)
#     Mean Error       : 4.124 px
#     Median Error     : 1.547 px
#     95th Percentile  : 2.813 px
# -------------------------------------------------------
#  ✅ ACCURACY & PASS RATES
#     Pass @ 5px       :  99.5%
#     Pass @ 4px       :  99.5%
#     Pass @ 2px       :  70.0%
#     Pass @ 1px       :  24.0%
# -------------------------------------------------------
#  ⚡ PERFORMANCE LATENCY
#     Mean Latency     : 21.64 ms/pair
#     Median Latency   : 13.64 ms/pair
# -------------------------------------------------------
#  💾 ARTIFACTS SAVED
#     Predictions CSV  -> predictions_manifest.csv
# ...
