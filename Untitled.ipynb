# %%
# !python generate_dataset.py
# Out:
# generating train: 100%|████████████████████| 5000/5000 [02:20<00:00, 35.68it/s]
# [train] wrote 5000 pairs -> dataset/train/labels.csv  (140.2s, 10 workers, chunksize=125)
# generating val: 100%|████████████████████████| 200/200 [00:06<00:00, 30.63it/s]
# [val] wrote 200 pairs -> dataset/val/labels.csv  (6.6s, 10 workers, chunksize=5)
# wrote dataset/meta.json

# %%
# !python src/dl_training.py
# Out:
# Selected Acceleration Device: mps
# TrainConfig(dataset_root='dataset', embed_dim=16, batch_size=32, epochs=45, lr=0.002, weight_decay=0.0001, pos_radius=1.0, exclusion_radius=6.0, margin=0.3, lambda_margin=1.0, init_logit_scale=10.0, num_workers=0, seed=42, checkpoint_path='drift_sense_model.pth', augment=True)
# Dataset Loaded. Scale ratio: 10.0
# [01/45] Train Loss 0.4878 (BCE 0.3991) | Val Err Mean  4.44px | Acc@5px 99.5% | Epoch Time: 144.1s
# [02/45] Train Loss 0.2749 (BCE 0.2719) | Val Err Mean  4.30px | Acc@5px 99.5% | Epoch Time: 138.9s
# [03/45] Train Loss 0.2666 (BCE 0.2646) | Val Err Mean  4.32px | Acc@5px 99.5% | Epoch Time: 143.5s
# [04/45] Train Loss 0.2622 (BCE 0.2608) | Val Err Mean  4.26px | Acc@5px 99.5% | Epoch Time: 145.1s
# [05/45] Train Loss 0.2602 (BCE 0.2591) | Val Err Mean  4.28px | Acc@5px 99.5% | Epoch Time: 142.2s
# [06/45] Train Loss 0.2594 (BCE 0.2582) | Val Err Mean  4.95px | Acc@5px 99.5% | Epoch Time: 145.6s
# ...

# %%
# !python localize.py
# Out:
# Hardware           : MPS Acceleration
# Timing Method      : Python time.perf_counter()
# ----------------------------------------
# n_pairs            : 200
# mean error (px)    : 1.859
# median error (px)  : 2.021
# p95 error (px)     : 3.193
# pass @ 5px         : 100.0%
# pass @ 4px         : 100.0%
# pass @ 2px         : 49.0%
# pass @ 1px         : 23.0%
# mean latency (ms)  : 12.679
# median latency(ms) : 10.951
# Predictions CSV    -> eval_out/predictions_manifest.csv
# worst-pair overlay -> eval_out/worst_pair_113_err3.5px.png
